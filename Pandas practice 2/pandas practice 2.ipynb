# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\pandaspractice1.csv")
df.head()
# Out:
#    Emp_ID     Name  Department   Age  Salary   Join_Date     City  \
# 0    1001    Dhruv          IT  22.0   75444  2022-10-25    Delhi
# 1    1002       Om  Operations  25.0   76522  2015-10-03   Mumbai
# 2    1003   Ishaan   Marketing  25.0   50737  2018-04-13  Kolkata
# 3    1004  Krishna     Finance  31.0   58647  2019-04-28  Chennai
# 4    1005       Om          HR  41.0   91353  2018-10-27  Chennai
#
#    Bonus_Percentage  Performance_Rating  Remote_Work
# 0             12.12                   1         True
# 1             12.05                   1        False
# 2             15.74                   3         True
# 3              9.32                   3         True
# 4             10.75                   4         True

# %%
df.shape
# Out:
# (51, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Emp_ID              51 non-null     int64
#  1   Name                51 non-null     object
#  2   Department          50 non-null     object
#  3   Age                 50 non-null     float64
#  4   Salary              51 non-null     int64
#  5   Join_Date           51 non-null     object
#  6   City                51 non-null     object
#  7   Bonus_Percentage    51 non-null     float64
#  8   Performance_Rating  51 non-null     int64
#  9   Remote_Work         51 non-null     bool
# dtypes: bool(1), float64(2), int64(3), object(4)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#             Emp_ID       Age        Salary  Bonus_Percentage  \
# count    51.000000  50.00000     51.000000         51.000000
# mean   1025.019608  38.98000  63457.823529         11.480784
# std      14.833058  11.54846  20252.356646          4.393724
# min    1001.000000  22.00000  32418.000000          5.250000
# 25%    1012.500000  30.25000  44039.000000          7.625000
# 50%    1025.000000  39.00000  63920.000000         10.750000
# 75%    1037.500000  46.00000  81217.500000         14.510000
# max    1050.000000  59.00000  96509.000000         19.760000
#
#        Performance_Rating
# count           51.000000
# mean             2.980392
# std              1.334019
# min              1.000000
# 25%              2.000000
# 50%              3.000000
# 75%              4.000000
# max              5.000000

# %%
df.columns
# Out:
# Index(['Emp_ID', 'Name', 'Department', 'Age', 'Salary', 'Join_Date', 'City',
#        'Bonus_Percentage', 'Performance_Rating', 'Remote_Work'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Emp_ID                0
# Name                  0
# Department            1
# Age                   1
# Salary                0
# Join_Date             0
# City                  0
# Bonus_Percentage      0
# Performance_Rating    0
# Remote_Work           0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Emp_ID                0
# Name                  0
# Department            0
# Age                   0
# Salary                0
# Join_Date             0
# City                  0
# Bonus_Percentage      0
# Performance_Rating    0
# Remote_Work           0
# dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# IT            13
# Finance       12
# Marketing     11
# Operations     9
# HR             4
# Name: count, dtype: int64

# %%
df['Age'].astype(int)
# Out:
# 0     22
# 1     25
# 2     25
# 3     31
# 4     41
# 6     58
# 7     45
# 8     28
# 9     46
# 11    34
# 12    23
# 13    45
# 14    46
# 15    39
# 16    59
# 17    47
# 18    35
# 19    30
# 20    31
# 21    42
# 22    38
# 23    27
# 24    37
# 25    22
# 26    40
# 27    57
# 28    46
# 29    51
# 30    41
# 31    41
# 32    36
# 33    54
# 34    23
# 35    31
# 36    54
# 37    53
# 38    32
# 39    45
# 40    57
# 41    33
# 42    50
# 43    56
# 44    22
# 45    22
# 46    58
# 47    27
# 48    39
# 49    37
# Name: Age, dtype: int32

# %%
max(df['Age'])
# Out:
# 59.0

# %%
min(df['Age'])
# Out:
# 22.0

# %%
pd.cut(df['Age'], bins=[20, 30, 40, 50], labels=['20s', '30s', '40s'])
# Out:
# 0     20s
# 1     20s
# 2     20s
# 3     30s
# 4     40s
# 6     NaN
# 7     40s
# 8     20s
# 9     40s
# 11    30s
# 12    20s
# 13    40s
# 14    40s
# 15    30s
# 16    NaN
# 17    40s
# 18    30s
# 19    20s
# 20    30s
# 21    40s
# 22    30s
# 23    20s
# 24    30s
# 25    20s
# 26    30s
# 27    NaN
# 28    40s
# 29    NaN
# 30    40s
# 31    40s
# 32    30s
# 33    NaN
# 34    20s
# 35    30s
# 36    NaN
# 37    NaN
# 38    30s
# 39    40s
# 40    NaN
# 41    30s
# 42    40s
# 43    NaN
# 44    20s
# 45    20s
# 46    NaN
# 47    20s
# 48    30s
# 49    30s
# Name: Age, dtype: category
# Categories (3, object): ['20s' < '30s' < '40s']

# %%
df['City'].value_counts()
# Out:
# City
# Chennai      18
# Delhi        11
# Kolkata      10
# Mumbai        7
# Bangalore     3
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# Emp_ID                48
# Name                  10
# Department             5
# Age                   29
# Salary                48
# Join_Date             48
# City                   5
# Bonus_Percentage      47
# Performance_Rating     5
# Remote_Work            2
# dtype: int64

# %%
df['Remote_Work'].value_counts()
# Out:
# Remote_Work
# False    26
# True     23
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.set_index('Emp_ID')
# Out:
#            Name  Department   Age  Salary   Join_Date       City  \
# Emp_ID
# 1001      Dhruv          IT  22.0   75444  2022-10-25      Delhi
# 1002         Om  Operations  25.0   76522  2015-10-03     Mumbai
# 1003     Ishaan   Marketing  25.0   50737  2018-04-13    Kolkata
# 1004    Krishna     Finance  31.0   58647  2019-04-28    Chennai
# 1005         Om          HR  41.0   91353  2018-10-27    Chennai
# 1007      Arjun          IT  58.0   90535  2021-10-28    Chennai
# 1008      Arjun     Finance  45.0   77883  2021-12-11    Chennai
# 1009      Dhruv  Operations  28.0   93360  2021-05-23    Chennai
# 1010     Vivaan   Marketing  46.0   81811  2018-07-28    Chennai
# 1012         Om          HR  34.0   49340  2017-02-09    Chennai
# 1013      Dhruv          IT  23.0   57257  2015-04-05     Mumbai
# 1014        Sai  Operations  45.0   46298  2020-03-14    Kolkata
# 1015     Aditya   Marketing  46.0   42372  2020-03-19    Chennai
# ...

# %%
df['Join_Date'] = pd.to_datetime(df['Join_Date'])

# %%
df['Join_Year'] = df['Join_Date'].dt.year
df['Join_Month'] = df['Join_Date'].dt.month

# %%
df.head()
# Out:
#    Emp_ID     Name  Department   Age  Salary  Join_Date     City  \
# 0    1001    Dhruv          IT  22.0   75444 2022-10-25    Delhi
# 1    1002       Om  Operations  25.0   76522 2015-10-03   Mumbai
# 2    1003   Ishaan   Marketing  25.0   50737 2018-04-13  Kolkata
# 3    1004  Krishna     Finance  31.0   58647 2019-04-28  Chennai
# 4    1005       Om          HR  41.0   91353 2018-10-27  Chennai
#
#    Bonus_Percentage  Performance_Rating  Remote_Work  Join_Year  Join_Month
# 0             12.12                   1         True       2022          10
# 1             12.05                   1        False       2015          10
# 2             15.74                   3         True       2018           4
# 3              9.32                   3         True       2019           4
# 4             10.75                   4         True       2018          10

# %%
df['Bonus_Amount'] = df['Salary'] * (df['Bonus_Percentage'] / 100)

# %%
df.head()
# Out:
#    Emp_ID     Name  Department   Age  Salary  Join_Date     City  \
# 0    1001    Dhruv          IT  22.0   75444 2022-10-25    Delhi
# 1    1002       Om  Operations  25.0   76522 2015-10-03   Mumbai
# 2    1003   Ishaan   Marketing  25.0   50737 2018-04-13  Kolkata
# 3    1004  Krishna     Finance  31.0   58647 2019-04-28  Chennai
# 4    1005       Om          HR  41.0   91353 2018-10-27  Chennai
#
#    Bonus_Percentage  Performance_Rating  Remote_Work  Join_Year  Join_Month  \
# 0             12.12                   1         True       2022          10
# 1             12.05                   1        False       2015          10
# 2             15.74                   3         True       2018           4
# 3              9.32                   3         True       2019           4
# 4             10.75                   4         True       2018          10
#
#    Bonus_Amount
# 0     9143.8128
# 1     9220.9010
# 2     7986.0038
# 3     5465.9004
# 4     9820.4475

# %%
df.groupby('Performance_Rating')['Salary'].mean()
# Out:
# Performance_Rating
# 1    62721.222222
# 2    52557.375000
# 3    65079.272727
# 4    68327.307692
# 5    69987.571429
# Name: Salary, dtype: float64

# %%
df.sort_values(['Performance_Rating', 'Salary'], ascending=[False, False]).head()
# Out:
#     Emp_ID    Name Department   Age  Salary  Join_Date       City  \
# 31    1032   Dhruv  Marketing  41.0   96509 2017-04-23     Mumbai
# 16    1017  Vihaan    Finance  59.0   92079 2018-09-14    Chennai
# 37    1038  Vivaan  Marketing  53.0   91570 2018-02-08  Bangalore
# 30    1031  Ishaan  Marketing  41.0   78682 2019-07-04    Kolkata
# 12    1013   Dhruv         IT  23.0   57257 2015-04-05     Mumbai
#
#     Bonus_Percentage  Performance_Rating  Remote_Work  Join_Year  Join_Month  \
# 31             11.17                   5        False       2017           4
# 16              6.46                   5         True       2018           9
# 37              5.76                   5        False       2018           2
# 30             17.97                   5         True       2019           7
# 12             19.53                   5        False       2015           4
#
#     Bonus_Amount
# 31    10780.0553
# 16     5948.3034
# 37     5274.4320
# 30    14139.1554
# ...
